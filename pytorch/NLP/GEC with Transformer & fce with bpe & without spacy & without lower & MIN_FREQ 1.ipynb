# %%
# import os
# os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

import random
import numpy as np
import torch

# SEED = 1234

# random.seed(SEED)
# np.random.seed(SEED)
# torch.manual_seed(SEED)
# torch.cuda.manual_seed(SEED)
# torch.backends.cudnn.deterministic = True

# %% [markdown]
# ## Preparing the Data

# %%
from torchtext.datasets import TranslationDataset

class GEC_DATASET(TranslationDataset):
    @classmethod
    def splits(cls, 
               exts, 
               fields, 
               root, 
               train="train", 
               validation="dev", 
               test="test", 
               **kwargs):
        
        return super(GEC_DATASET, cls).splits(exts=exts, 
                                      fields=fields,
                                      path=root, 
                                      root=root,
                                      train=train, 
                                      validation=validation, 
                                      test=test,
                                      **kwargs)

# %%
from torchtext.data import Field
from torchtext.data import BucketIterator

def prepare_data(root):
    src_field = Field(init_token="<sos>", eos_token="<eos>", 
                      tokenize=lambda sentence: sentence.split(' '), 
                      batch_first=True)
    trg_field = Field(init_token="<sos>", eos_token="<eos>", 
                      tokenize=lambda sentence: sentence.split(' '), 
                      batch_first=True)
        
    train_set, valid_set, test_set = GEC_DATASET.splits(exts=('.src', '.trg'), 
                                                        fields=(src_field, trg_field),
                                                        root=root,
                                                        filter_pred=lambda sentence: 
                                                        len(vars(sentence)['src']) < MAX_LEN 
                                                        and len(vars(sentence)['trg']) < MAX_LEN)

    src_field.build_vocab(train_set, min_freq=MIN_FREQ)
    trg_field.build_vocab(train_set, min_freq=MIN_FREQ)

    train_iter, valid_iter, test_iter = BucketIterator.splits(
        datasets=(train_set, valid_set, test_set), 
        batch_size=BATCH_SIZE,
        device=DEVICE)
    
    return src_field, trg_field, train_iter, valid_iter, test_iter, train_set, valid_set, test_set

# %% [markdown]
# ## Building the Model

# %% [markdown]
# ### Encoder

# %%
import torch.nn as nn

class Encoder(nn.Module):
    def __init__(self, 
                input_dim, 
                hid_dim, 
                n_layers, 
                n_heads, 
                pf_dim, 
                dropout):
        
        super().__init__()
        
        self.tok_embedding = nn.Embedding(input_dim, hid_dim)
        
        self.pos_embedding = nn.Embedding(MAX_LEN + 1, hid_dim)  # why + 1?
        self.scale = torch.sqrt(torch.tensor([hid_dim], dtype=torch.float, device=DEVICE))

        self.layers = nn.ModuleList([EncoderLayer(hid_dim, 
                                                 n_heads, 
                                                 pf_dim, 
                                                 dropout)
                                    for _ in range(n_layers)])
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, src, src_mask):
        # (in)  src: [batch_size, src_len]
        # (in)  src_mask: [batch_size, 1, 1, src_len]
        # (out) src: [batch_size, src_len, hid_dim]
        
        batch_size = src.shape[0]
        src_len = src.shape[1]
        
        # (out) pos: [batch_size, src_len]
        pos = torch.arange(0, src_len).unsqueeze(0).repeat(batch_size, 1).to(DEVICE)
        
        # (in)  src
        # (in)  pos
        # (out) src: [batch_size, src_len, hid_dim]
        src = self.dropout(
            self.tok_embedding(src) * self.scale + self.pos_embedding(pos))
        
        for layer in self.layers:
            src = layer(src, src_mask)
            
        return src

# %% [markdown]
# ### Encoder Layer

# %%
class EncoderLayer(nn.Module):
    def __init__(self, 
                hid_dim, 
                n_heads, 
                pf_dim, 
                dropout):
        
        super().__init__()
        
        self.self_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout)
        self.positionwise_feedforward = PositionwiseFeedforwardLayer(hid_dim, pf_dim, dropout)
        
        self.dropout = nn.Dropout(dropout)
        self.layer_norm = nn.LayerNorm(hid_dim)
        
    def forward(self, src, src_mask):
        # (in)  src: [batch_size, src_len, hid_dim]
        # (in)  src_mask: [batch_size, 1, 1, src_len]
        # (out) src: [batch_size, src_len, hid_dim]
        
        _src, _ = self.self_attention(src, src, src, src_mask)
        
        src = self.layer_norm(src + self.dropout(_src))
        
        _src = self.positionwise_feedforward(src)
        
        src = self.layer_norm(src + self.dropout(_src))
        
        return src

# %% [markdown]
# ### Multi Head Attention Layer

# %%
class MultiHeadAttentionLayer(nn.Module):
    def __init__(self, hid_dim, n_heads, dropout):
        
        super().__init__()
        
        assert hid_dim % n_heads == 0
        
        self.hid_dim = hid_dim
        self.n_heads = n_heads
        self.head_dim = hid_dim // n_heads
        
        self.fc_q = nn.Linear(hid_dim, hid_dim)
        self.fc_k = nn.Linear(hid_dim, hid_dim)
        self.fc_v = nn.Linear(hid_dim, hid_dim)
        
        self.fc_o = nn.Linear(hid_dim, hid_dim)
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.tensor([self.head_dim], dtype=torch.float, device=DEVICE))
        
    def forward(self, query, key, value, mask=None):
        # (in)  qeury: [batch_size, query_len, hid_dim]
        # (in)  key: [batch_size, query_len, hid_dim]
        # (in)  value: [batch_size, query_len, hid_dim]
        
        batch_size = query.shape[0]
        
        # (in)  query
        # (in)  key
        # (in)  value
        # (out) Q: [batch_size, seq_len, hid_dim]
        # (out) K: [batch_size, seq_len, hid_dim]
        # (out) V: [batch_size, seq_len, hid_dim]
        Q = self.fc_q(query)
        K = self.fc_k(key)
        V = self.fc_v(value)
        
        # (out) Q: [batch_size, n_heads, query_len, head_dim]
        # (out) K: [batch_size, n_heads, key_len, head_dim]
        # (out) V: [batch_size, n_heads, value_len, head_dim]
        Q = Q.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        K = K.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        V = V.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        
        # (in)  Q
        # (in)  K
        # (out) energy: [batch_size, n_heads, query_len, key_len]
        energy = torch.matmul(Q, K.permute(0, 1, 3, 2)) / self.scale
        
        if mask is not None:
            energy = energy.masked_fill(mask==0, -1e10)
        
        # (in)  energy
        # (out) attention: [batch_size, n_heads, query_len, key_len]
        attention = torch.softmax(energy, dim=-1)  # why dim=-1?
        
        # (in)  attention
        # (out) x: [batch_size, n_heads, query_len, head_dim]
        x = torch.matmul(
            self.dropout(attention), V)
        
        # (in)  x 
        # (out) x: [batch_size, query_len, n_heads, head_dim]
        x = x.permute(0, 2, 1, 3).contiguous()
        
        # (in)  x
        # (out) x: [batch_size, query_len, hid_dim]
        x = x.view(batch_size, -1, self.hid_dim)
        
        # (in)  x
        # (out) x: [batch_size, query_len, hid_dim]
        x = self.fc_o(x)
        
        return x, attention

# %% [markdown]
# ### Position-wise Feedforward Layer

# %%
class PositionwiseFeedforwardLayer(nn.Module):
    def __init__(self, hid_dim, pf_dim, dropout):
        
        super().__init__()
        
        self.fc_1 = nn.Linear(hid_dim, pf_dim)
        self.fc_2 = nn.Linear(pf_dim, hid_dim)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x):
        
        x = self.dropout(
            torch.relu(
                self.fc_1(x)))
        
        x = self.fc_2(x)
        
        return x

# %% [markdown]
# ### Decoder

# %%
class Decoder(nn.Module):
    def __init__(self, 
                output_dim, 
                hid_dim, 
                n_layers, 
                n_heads, 
                pf_dim, 
                dropout):
        
        super().__init__()
        
        self.tok_embedding = nn.Embedding(output_dim, hid_dim)
        
        self.pos_embedding = nn.Embedding(MAX_LEN + 1, hid_dim)
        self.scale = torch.sqrt(torch.tensor([hid_dim], dtype=torch.float, device=DEVICE))
        
        self.layers = nn.ModuleList([DecoderLayer(hid_dim, 
                                                 n_heads, 
                                                 pf_dim, 
                                                 dropout)
                                    for _ in range(n_layers)])
        
        self.dropout = nn.Dropout(dropout)
        
        self.fc_out = nn.Linear(hid_dim, output_dim)
                
    def forward(self, trg, enc_src, trg_mask, src_mask):
        # (in)  trg: [batch_size, trg_len]
        # (in)  enc_src: [batch_size, src_len. hid_dim]
        # (in) trg_mask: [batch_size, 1, trg_len, trg_len]
        # (in) src_mask: [batch_size, 1, 1, src_len]
        # (out) output: [batch_size, trg_len, trg_vocab_size]
        # (out) attention: [batch_size, n_heads, trg_len, src_len]
        
        batch_size = trg.shape[0]
        trg_len = trg.shape[1]
        
        pos = torch.arange(0, trg_len, device=DEVICE).unsqueeze(0).repeat(batch_size, 1)
        
        # (in)  trg
        # (in)  pos
        # (out) trg: [batch_size, trg_len, hid_dim]
        trg = self.dropout(
            self.tok_embedding(trg) * self.scale + self.pos_embedding(pos))
        
        for layer in self.layers:
            trg, attention = layer(trg, enc_src, trg_mask, src_mask)
            
        # In PyTorch, the softmax operation is contained within our loss function, 
        # so we do not explicitly need to use a softmax layer here.
        output = self.fc_out(trg)
        
        return output, attention

# %% [markdown]
# ### Decoder Layer

# %%
class DecoderLayer(nn.Module):
    def __init__(self, 
                hid_dim, 
                n_heads, 
                pf_dim, 
                dropout):
        
        super().__init__()
        
        self.self_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout)
        self.encoder_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout)
        self.positionwise_feedforward = PositionwiseFeedforwardLayer(hid_dim, pf_dim, dropout)
        
        self.dropout = nn.Dropout(dropout)
        self.layer_norm = nn.LayerNorm(hid_dim)
        
    def forward(self, trg, enc_src, trg_mask, src_mask):
        # (in)  trg: [batch_size, trg_len, hid_dim]
        # (in)  enc_src: [batch_size, src_len, hid_dim]
        # (in)  trg_mask: [batch_size, 1, trg_len, trg_len]
        # (in)  src_mask: [batch_size, 1, 1, src_len]
        # (out) trg: [batch_size, trg_len, hid_dim]
        # (out) attention: [batch_size, n_heads, trg_len, src_len]
        
        _trg, _ = self.self_attention(trg, trg, trg, trg_mask)
        
        trg = self.layer_norm(trg + self.dropout(_trg))
        
        _trg, attention = self.encoder_attention(trg, enc_src, enc_src, src_mask)
        
        trg = self.layer_norm(trg + self.dropout(_trg))
        
        _trg = self.positionwise_feedforward(trg)
        
        trg = self.layer_norm(trg + self.dropout(_trg))
        
        return trg, attention

# %% [markdown]
# ### Seq2Seq

# %%
class Seq2Seq(nn.Module):
    def __init__(self, 
                encoder, 
                decoder, 
                src_pad_idx, 
                trg_pad_idx):
        
        super().__init__()
        
        self.encoder = encoder
        self.decoder = decoder
        
        self.src_pad_idx = src_pad_idx
        self.trg_pad_idx = trg_pad_idx
        
    def forward(self, src, trg):
        # (in)  src: [batch_size, src_len]
        # (in)  trg: [batch_size, trg_len]
        # (out) output: [batch_size, trg_len, trg_vocab_size]
        # (out) attention: [batch_size, dec_heads, trg_len, src_len]
        
        # (in)  src
        # (out) src_mask: [batch_size, 1, 1, src_len]
        src_mask = self.make_src_mask(src)
        # (in)  trg
        # (out) trg_mask: [batch_size, 1, trg_len, trg_len]
        trg_mask = self.make_trg_mask(trg)
        
        # Encode.
        
        # (in)  src
        # (in)  src_mask
        # (out) enc_src: [batch_size, src_len, hid_dim]
        enc_src = self.encoder(src, src_mask)
        
        # Decode.
        
        # (in)  trg
        # (in)  enc_src
        # (in)  trg_mask
        # (in)  src_mask
        # (out) output: [batch_size, trg_len, trg_vocab_size]
        # (out) attention: [batch_size, dec_heads, trg_len, src_len]
        output, attention = self.decoder(trg, enc_src, trg_mask, src_mask)
        
        return output, attention
        
    def make_src_mask(self, src):
        # (in) src: [batch_size, src_len]
        # (out) src_mask: [batch_size, 1, 1, src_len]
        
        src_mask = (src != self.src_pad_idx).unsqueeze(1).unsqueeze(2)
        
        return src_mask
    
    def make_trg_mask(self, trg):
        # (in) trg: [batch_size, trg_len]
        # (out) trg_mask: [batch_size, 1, trg_len, trg_len]
        
        # (in) trg
        # (out) trg_pad_mask: [batch_size, 1, 1, trg_len]
        trg_pad_mask = (trg != self.trg_pad_idx).unsqueeze(1).unsqueeze(2)
        
        trg_len = trg.shape[1]
        # (out) trg_sub_mask: [trg_len, trg_len]
        trg_sub_mask = torch.tril(
            torch.ones((trg_len, trg_len), device=DEVICE)).bool()
        
        # (in)  trg_pad_mask
        # (in)  trg_sub_mask
        # (out) trg_mask: [batch_size, 1, trg_len, trg_len]
        trg_mask = trg_pad_mask & trg_sub_mask
        
        return trg_mask

# %% [markdown]
# ## Training the Seq2Seq Model

# %%
def init_weights(m):
    if hasattr(m, "weight") and m.weight.dim() > 1:  # dim <= 1: layernorm
        nn.init.xavier_uniform_(m.weight.data)

# %% [markdown]
# ### Training and Validating

# %%
def _train(model, iterator, optimizer, criterion):
    
    model.train()
    
    epoch_loss = 0
    
    for batch in iterator:
        
        optimizer.zero_grad()
        
        src = batch.src
        trg = batch.trg
        
        # As we want our model to predict the <eos> token but not have it be an input 
        # into our model we simply slice the <eos> token off the end of the sequence. 
        output, _ = model(src, trg[:,:-1])
            
        output = output.contiguous().view(-1, output.shape[-1])
        # We then calculate our loss using the original trg tensor with the <sos> token 
        # sliced off the front, leaving the <eos> token:
        trg = trg[:,1:].contiguous().view(-1)
        loss = criterion(output, trg)
        
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), CLIP)
        
        optimizer.step()
        
        epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def _evaluate(model, iterator, criterion):
    
    model.eval()
    
    epoch_loss = 0
    
    with torch.no_grad():
        
        for batch in iterator:
            
            src = batch.src
            trg = batch.trg
            
            output, _ = model(src, trg[:, :-1])
            
            output = output.contiguous().view(-1, output.shape[-1])
            trg = trg[:, 1:].contiguous().view(-1)
            loss = criterion(output, trg)
            
            epoch_loss += loss.item()
            
    return epoch_loss / len(iterator)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time % 60)
    
    return elapsed_mins, elapsed_secs

# %%
import time
import math

def train(train_iter, valid_iter, model, criterion, optimizer):
    
    best_valid_loss = float("inf")

    for epoch in range(N_EPOCHS):

        start_time = time.time()

        train_loss = _train(model, train_iter, optimizer, criterion)
        valid_loss = _evaluate(model, valid_iter, criterion)

        end_time = time.time()

        epoch_mins, epoch_secs = epoch_time(start_time, end_time)

        if valid_loss < best_valid_loss:
            best_valid_loss = valid_loss
            torch.save(model.state_dict(), PT)

        print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
        print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
        print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')

# %%
def test(test_iter, model, criterion):
    test_loss = _evaluate(model, test_iter, criterion)

    print(f'| Test Loss: {test_loss:.3f} | Test PPL: {math.exp(test_loss):7.3f} |')

# %% [markdown]
# ## Inference

# %%
def correct_sentence(sentence, src_field, trg_field, model):
    
    model.eval()
    
    # Prepares for data.
    
    if isinstance(sentence, str):
        tokens = [token for token in sentence.split(' ')]
    else:
        tokens = sentence
    tokens = [src_field.init_token] + tokens + [src_field.eos_token]
    
    # Encode.
    
    src_indexes = [src_field.vocab.stoi[token] for token in tokens]
    src_tensor = torch.tensor(src_indexes, dtype=torch.long, device=DEVICE).unsqueeze(0)
    
    src_mask = model.make_src_mask(src_tensor)
    
    with torch.no_grad():
        enc_src = model.encoder(src_tensor, src_mask)
        
    # Decode.
    
    trg_indexes = [trg_field.vocab.stoi[trg_field.init_token]]
    
    for i in range(MAX_LEN):
        trg_tensor = torch.tensor(trg_indexes, dtype=torch.long, device=DEVICE).unsqueeze(0)
        
        trg_mask = model.make_trg_mask(trg_tensor)
        
        with torch.no_grad():
            output, attention = model.decoder(trg_tensor, enc_src, trg_mask, src_mask)
        
        pred_token = output.argmax(2)[:, -1].item()
        
        trg_indexes.append(pred_token)
        
        if pred_token == trg_field.vocab.stoi[trg_field.eos_token]:
            break
            
    trg_tokens = [trg_field.vocab.itos[i] for i in trg_indexes]

    return trg_tokens[1:], attention

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

def display_attention(sentence, translation, attention, n_heads=8, n_rows=4, n_cols=2):
    
    assert n_rows * n_cols == n_heads
    
    fig = plt.figure(figsize=(15, 25))
    
    for i in range(n_heads):
        
        # Gets the attention of the i^th head.
        _attention = attention.squeeze(0)[i].cpu().detach().numpy()
        
        ax = fig.add_subplot(n_rows, n_cols, i + 1)        
        cax = ax.matshow(_attention, cmap="bone")
        
        ax.tick_params(labelsize=12)
        
        ax.set_xticklabels([''] + ['<sos>'] + [t.lower() for t in sentence] + ['<eos>'], 
                          rotation=45)
        ax.set_yticklabels([''] + translation)
        
        ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
        
    plt.show()
    plt.close()

# %%
def inference(dataset, src_field, trg_field, model):
    
    for _ in range(10):
        example_idx = random.randint(1, len(dataset))
        
        src = vars(dataset.examples[example_idx])['src']
        trg = vars(dataset.examples[example_idx])['trg']

        print(f"src = {' '.join(src).replace('@@', '')}")
        print(f"trg = {' '.join(trg).replace('@@', '')}")
        
        correction, attention = correct_sentence(src, src_field, trg_field, model)
        
        print(f"out = {' '.join(correction[:-1]).replace('@@', '')}")
        
        print('---')
        
#         display_attention(src, correction, attention)
    
    print()

# %% [markdown]
# ## BLEU

# %%
from torchtext.data.metrics import bleu_score

def calculate_bleu(data, src_field, trg_field, model):
    
    trgs = []
    pred_trgs = []
    
    for datum in data:
        
        src = vars(datum)["src"]
        trg = vars(datum)["trg"]
        
        pred_trg, _ = correct_sentence(src, src_field, trg_field, model)
        
        # Cuts off <eos>.
        pred_trg = pred_trg[:-1]

        pred_trgs.append(pred_trg)
        trgs.append([trg])
        
    return bleu_score(pred_trgs, trgs)

# %% [markdown]
# ## Main

# %%
import torch
import torch.optim as optim

if __name__ == '__main__':
    DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    DATASET = "fce with bpe"
    
    # Prepares for data.
    ROOT = f"../data/{DATASET}/parallel"
    MAX_LEN = 100
    MIN_FREQ = 1
    BATCH_SIZE = 64

    src_field, trg_field, train_iter, valid_iter, test_iter, train_set, valid_set, test_set = prepare_data(root=ROOT)
    
    # Model.
    INPUT_DIM = len(src_field.vocab)
    OUTPUT_DIM = len(trg_field.vocab)
    HID_DIM = 512
    ENC_LAYERS = 6
    DEC_LAYERS = 6
    ENC_HEADS = 8
    DEC_HEADS = 8
    ENC_PF_DIM = 2048
    DEC_PF_DIM = 2048
    ENC_DROPOUT = 0.1
    DEC_DROPOUT = 0.1
    
    SRC_PAD_IDX = src_field.vocab.stoi[src_field.pad_token]
    TRG_PAD_IDX = trg_field.vocab.stoi[trg_field.pad_token]
    
    enc = Encoder(INPUT_DIM, 
              HID_DIM, 
              ENC_LAYERS, 
              ENC_HEADS, 
              ENC_PF_DIM, 
              ENC_DROPOUT)

    dec = Decoder(OUTPUT_DIM, 
              HID_DIM, 
              DEC_LAYERS, 
              DEC_HEADS, 
              DEC_PF_DIM, 
              DEC_DROPOUT)    

    model = Seq2Seq(enc, dec, SRC_PAD_IDX, TRG_PAD_IDX).to(DEVICE)
    model.apply(init_weights)
    
    # Criterion.
    criterion = nn.CrossEntropyLoss(ignore_index=TRG_PAD_IDX)
    
    # Optimizer.
    LEARNING_RATE = 0.0001
    
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE, betas=(0.9, 0.98), eps=1e-09)
    
    # Trains and validates.
    N_EPOCHS = 20
    CLIP = 1
    PT = f"transformer with {DATASET}.pt"
    
    train(train_iter, valid_iter, model, criterion, optimizer)
    
    # Tests.
    model.load_state_dict(torch.load(PT))
    test(test_iter, model, criterion)
# Out:
# Epoch: 01 | Time: 1m 28s
# 	Train Loss: 5.274 | Train PPL: 195.203
# 	 Val. Loss: 3.858 |  Val. PPL:  47.376
# Epoch: 02 | Time: 1m 29s
# 	Train Loss: 3.807 | Train PPL:  45.037
# 	 Val. Loss: 3.175 |  Val. PPL:  23.938
# Epoch: 03 | Time: 1m 29s
# 	Train Loss: 3.273 | Train PPL:  26.390
# 	 Val. Loss: 2.828 |  Val. PPL:  16.914
# Epoch: 04 | Time: 1m 29s
# 	Train Loss: 2.939 | Train PPL:  18.888
# 	 Val. Loss: 2.598 |  Val. PPL:  13.431
# Epoch: 05 | Time: 1m 28s
# 	Train Loss: 2.689 | Train PPL:  14.719
# 	 Val. Loss: 2.444 |  Val. PPL:  11.524
# Epoch: 06 | Time: 1m 29s
# 	Train Loss: 2.484 | Train PPL:  11.990
# 	 Val. Loss: 2.333 |  Val. PPL:  10.314
# Epoch: 07 | Time: 1m 30s
# 	Train Loss: 2.313 | Train PPL:  10.102
# 	 Val. Loss: 2.225 |  Val. PPL:   9.258
# Epoch: 08 | Time: 1m 28s
# 	Train Loss: 2.160 | Train PPL:   8.668
# 	 Val. Loss: 2.165 |  Val. PPL:   8.714
# Epoch: 09 | Time: 1m 28s
# 	Train Loss: 2.023 | Train PPL:   7.560
# 	 Val. Loss: 2.101 |  Val. PPL:   8.172
# Epoch: 10 | Time: 1m 28s
# 	Train Loss: 1.900 | Train PPL:   6.684
# 	 Val. Loss: 2.071 |  Val. PPL:   7.931
# Epoch: 11 | Time: 1m 28s
# 	Train Loss: 1.787 | Train PPL:   5.970
# 	 Val. Loss: 2.035 |  Val. PPL:   7.650
# Epoch: 12 | Time: 1m 29s
# 	Train Loss: 1.684 | Train PPL:   5.387
# 	 Val. Loss: 1.999 |  Val. PPL:   7.384
# Epoch: 13 | Time: 1m 31s
# 	Train Loss: 1.588 | Train PPL:   4.896
# 	 Val. Loss: 1.982 |  Val. PPL:   7.259
# Epoch: 14 | Time: 1m 28s
# 	Train Loss: 1.497 | Train PPL:   4.469
# 	 Val. Loss: 1.973 |  Val. PPL:   7.195
# Epoch: 15 | Time: 1m 29s
# 	Train Loss: 1.412 | Train PPL:   4.103
# 	 Val. Loss: 1.974 |  Val. PPL:   7.196
# Epoch: 16 | Time: 1m 27s
# 	Train Loss: 1.337 | Train PPL:   3.807
# 	 Val. Loss: 1.973 |  Val. PPL:   7.194
# Epoch: 17 | Time: 1m 29s
# 	Train Loss: 1.262 | Train PPL:   3.532
# 	 Val. Loss: 1.945 |  Val. PPL:   6.994
# Epoch: 18 | Time: 1m 28s
# 	Train Loss: 1.191 | Train PPL:   3.290
# 	 Val. Loss: 1.949 |  Val. PPL:   7.022
# Epoch: 19 | Time: 1m 28s
# 	Train Loss: 1.126 | Train PPL:   3.083
# 	 Val. Loss: 1.947 |  Val. PPL:   7.005
# Epoch: 20 | Time: 1m 28s
# 	Train Loss: 1.062 | Train PPL:   2.891
# 	 Val. Loss: 1.951 |  Val. PPL:   7.037
# | Test Loss: 2.855 | Test PPL:  17.379 |

# %%
print("training inference")
inference(train_set, src_field, trg_field, model)
# Out:
# training inference
# src = If you are a good ob server , it 's a great chance to know what your son or daughter would like to have for her birthday or for any other special date .
# trg = If you are a good ob server , it 's a great chance to get to know what your son or daughter would like to have for their birthday or for any other special occasion .
# out = If you are a good chance to ask for a special or what it 's possible for you have to do or just be a good chance to get any other hand , because you can do or know what your own clothes .
# ---
# src = I feel like I was a hero at that moment , even though I 'd never though of it before .
# trg = I felt like I was a hero at that moment , even though I 'd never thought of it before .
# out = I 'd like to feel that I was a child at that moment , even though I 'd never thought of it .
# ---
# src = They were so kind to me that we soon became good friends .
# trg = They were so kind to me that we soon became good friends .
# out = They were kind to me that we became good friends and became kind .
# ---
# src = Students start their day at the G y m , where they learn the importance of being fit , that is way I suggest to film this activity .
# trg = Students start their day at the G y m , where they learn the importance of being fit , that is why I suggest filming this activity .
# out = The teacher is that , they suggest filming their sports lesson , the day at the end of the day they learn their knowledge .
# ---
# src = They were in the shopping centre , and the problem was that Nick was n't alone , he was with a very beautiful girl .
# trg = They were in the shopping centre , and the problem was that Nick was n't alone , he was with a very beautiful girl .
# out = They were in the shopping centre , and the problem was that Nick was n't very beautiful , because he was going shopping with a big problem .
# ---
# src = Ad ults think that new coloured clothes , that young people wear are horrible an very un traditional .
# trg = Ad ults think that the new coloured clothes that young people wear are horrible and very un traditional .
# out = First that the new clothes that are really strong , and un rich - shoes .
# ---
# src = About my Accommodation I prefer the tents , I like them , every year I go 15 days out with my tent and some friends .
# trg = About my accommodation , I prefer tents . I like them . Every year I go 15 days out with my tent and some friends .
# out = About my accommodation , I like camping every year , I go camping with some friends and I spend them in a tent .
# ---
# src = Is it necessary to ask for Tra vell ers ' Che ques ?
# trg = Is it necessary to ask for Tra vell ers ' Che ques ?
# out = Is it necessary to ask for ' Is it necessary to take necessary ?
# ---
# src = And she realized that if something happens to her best fri ed , it would be her fault and her best friend 's parents would blame her for it .
# trg = And she realized that if something happened to her best friend , it would be her fault and her best friend 's parents would blame her for it .
# out = And if it 's good to her best friend , she thought that her parents would be able to go to her fault and Pat ' .
# ---
# src = An nabel K oh
# trg = An nabel K oh
# out = An An nabel
# ---

# %%
print("validating inference")
inference(valid_set, src_field, trg_field, model)
# Out:
# validating inference
# src = I had to wait in overcrowded hall .
# trg = I had to wait in the overcrowded hall .
# out = I had to wait in front of the hall .
# ---
# src = In the past it was impossible to go to Paris from B ar cel on a and come back in one day .
# trg = In the past it was impossible to go to Paris from B ar cel on a and come back in one day .
# out = In the end it was possible to go back to a place to the theatre 's restaurant and to go back to the past .
# ---
# src = Of course in the begining it is hard but you can learn a lot and if you 're good at you 'll also earn some money .
# trg = Of course in the beginning it is hard but you can learn a lot and if you 're good at it you 'll also earn some money .
# out = Of course it is a good thing if you can do some good ones in the future but also if you are at the same place and also good ones .
# ---
# src = love
# trg = love
# out = love
# ---
# src = So could you give us permission to go ?
# trg = So could you give us permission to go ?
# out = So could you give us us some information ?
# ---
# src = Nowadays we have cap it ali s m , free market lots of priv e te shops , markets and super - markets .
# trg = Nowadays we have cap it ali s m , free market , lots of private shops , markets and supermarkets .
# out = Nowadays , we have lots of free time , shops centres , shops centres and air cars centres .
# ---
# src = 13th June 2000
# trg = 13th June 2000
# out = 13th June 2000
# ---
# src = And for the second question .
# trg = And for the second question .
# out = And the second question for is .
# ---
# src = All her friends were amazed at her change and started tru sting her at once .
# trg = All her friends were amazed at how she had changed and started tru sting her at once .
# out = All her friends were n't at keeping secrets and started to say that our friends were always bored .
# ---
# src = W al es
# trg = W al es
# out = W al al
# ---

# %%
print("testing inference")
inference(test_set, src_field, trg_field, model)
# Out:
# testing inference
# src = Even if the archit ec tur al style may seem a bit ' heavy , this building is really a masterpiece with no similar comparison all over the world .
# trg = Even if the archit ec tur al style may seem a bit heavy , this building is really a masterpiece with no real comparison anywhere in the world .
# out = Even if this is a really common way by computers ' world also the Internet , the world has made into b to osity .
# ---
# src = And also it 's time to make new system which makes us use easier and more simple , so far more people can enjoy computer more than before .
# trg = And also it 's time to make new systems which makes use easier and more simple , so far more people can enjoy computers than before .
# out = And more than new technology makes people easier , so it 's also easy to do more than we can go to the computer and also make new machines .
# ---
# src = Of course it is a pity that Mr. Brown has been ill , but we are happy that you are com eing now .
# trg = Of course it is a pity that Mr. Brown has been ill , but we are happy that you are coming now .
# out = Of course , it is a good thing that you are excellent , but we have been told that it is wonderful .
# ---
# src = Dear Mrs Maria Smith ,
# trg = Dear Mrs Maria Smith ,
# out = Dear Mrs Smith ,
# ---
# src = You asked me for some suggestions for your free afternoon .
# trg = You asked me for some suggestions for your free afternoon .
# out = You asked me for some free time for your English .
# ---
# src = First of all , your group has been booked into Pa la ce Hotel which is very convenient to stay and has beautiful landscape .
# trg = First of all , your group has been booked into Pa la ce Hotel which is very convenient to stay in and has a beautiful landscape .
# out = First of all , the majority has been very interesting and has been to your group 's body on Monday club .
# ---
# src = It ca n't be difficult to find , because is very near of the conf er ence .
# trg = It ca n't be difficult to find , because it is very near to the conf er ence .
# out = It is very difficult to find the air , because of people .
# ---
# src = Dear Mrs Maria Smith
# trg = Dear Mrs Smith
# out = Dear Mrs Smith
# ---
# src = Can you think you have every information you need whenever you want ?
# trg = Can you imagine you have every piece of information you need whenever you want it ?
# out = Can you think you need anything whenever you have ?
# ---
# src = Computer magic .
# trg = Computer magic .
# out = Life .
# ---

# %%
bleu = calculate_bleu(test_set, src_field, trg_field, model)
print(f"BLEU score = {bleu * 100:.2f}")
